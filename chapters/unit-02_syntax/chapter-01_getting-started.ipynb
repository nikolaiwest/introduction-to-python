# %% [markdown]
# # **UE2: Syntax**
#
# # **Chapter 01:** Getting Started with Python
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/2560px-Python_logo_and_wordmark.svg.png" height="150">
#
# ## 🌟 Introduction
#
# Welcome to **Unit 2** of our Python journey! In the previous unit, you learned *how to set up your development environment* for Python programming. Now, it's time to dive into Python itself and begin *writing actual code*.
#
# Python has grown to become one of **the most popular programming languages** in the world, beloved by beginners and experts alike. Its clear, readable syntax makes it an excellent first programming language, while its powerful features and extensive ecosystem make it suitable for building everything from *simple scripts* to *complex applications* in fields ranging from *web development* to *artificial intelligence*.
#
# > **Tip:** Don't worry if you don't understand everything immediately. Programming is a skill that develops through practice. Focus on understanding the core concepts, and try to write small pieces of code regularly to reinforce your learning.
#
# In this chapter, we'll introduce you to Python, help you set up your environment, and guide you through writing your first Python program.
#
# ## 📚 Chapter Outline
#
# > **[Chapter 1.1: Introduction to Python](#chapter-11-introduction-to-python)**
# - **Python Overview:** The origin, philosophy, and key features of Python.
# - **Key Features:** The fundamental characteristics that make Python unique and powerful.
# - **Python's Versatility:** Popular libraries and frameworks demonstrating Python's wide application range.
#
# > **[Chapter 1.2: Setting Up An Environment](#chapter-12-setting-up-an-environment)**
# - **Installing Python:** Platform-specific instructions for installing Python.
# - **Choosing Development Tools:** Options for IDEs and text editors.
# - **Virtual Environments:** Creating isolated environments for Python projects.
#
# > **[Chapter 1.3: Your First Python Program](#chapter-13-your-first-python-program)**
# - **Writing Python Code:** Different methods for writing and running Python code.
# - **Understanding the Code:** Explanation of basic Python syntax.
# - **Python's Interactive Mode:** Using Python's immediate execution environment.
#
# > **[Chapter 1.4: Coding Challenge](#chapter-14-coding-challenge)**
# - **Challenge Description:** Create a simple Python script that introduces yourself.
#
# ## 💡 What You Will Learn
#
# By the end of this chapter, you will be able to:
# - Understand the *history*, *philosophy*, and *key features* of Python.
# - Recognize Python's versatility across different domains through its ecosystem of libraries.
# - Set up and configure your Python development environment.
# - Create and use **virtual environments** for project isolation.
# - Write and run your first Python program using different methods.
# - Navigate the basics of Python's syntax and structure.
# - Use Python's **interactive mode** for quick experimentation.
#
# [⬆️ Back to the Top](#ue2-syntax)
#
# ---

# %% [markdown]
# ## **Chapter 1.1:** Introduction to Python
#
# Before we dive into the technical details, let's take a moment to talk about what you're about to learn and why it matters. If you're reading this, you've (probably) completed the setup process in **[Unit 1](https://github.com/nikolaiwest/introduction-to-python/blob/main/chapters/unit-01_setup/chapter-00_outline-and-best-practices.ipynb)**, which means you're ready to start writing actual Python code. This is an exciting milestone!
#
# In this chapter, we're going to build your *foundational understanding of Python* as a programming language. We won't be writing much code just yet... instead, we're going to explore the "big picture" questions: What is Python? Where did it come from? Why has it become so popular? And most importantly, what makes it a great choice for your first programming language (or your next one)?
#
# Think of this chapter as your orientation session. In a traditional classroom, an instructor would spend the first session explaining these concepts, answering questions, and helping you understand the landscape before diving into syntax. Since you're learning at your own pace, we've captured all of that contextual information here. Take your time with this material—understanding the **"why"** behind Python will make learning the **"how"** much more meaningful.
#
# > **Learning Tip:** You might be eager to start coding right away, and that's great! But if this is your first time learning to code, resist the urge to skip this chapter. The context you gain here will help everything else make sense. Think of it as learning the rules of chess before playing your first game—you could jump right in, but understanding the fundamentals first makes the journey smoother.

# %% [markdown]
# ### 🔍 Understanding Python: *The Language That Changed Programming*
#
# Python was created by *Guido van Rossum* (often affectionately called Python's ["Benevolent Dictator For Life"](https://realpython.com/ref/glossary/bdfl/) by the community) and first released in `1991`. But Python wasn't an overnight success. It took years of development and community adoption to become what it is today.
#
# Now, over three decades later, Python consistently ranks as one of the top three most popular programming languages worldwide. But why? What makes Python special when there are hundreds of programming languages to choose from?
#
# The answer lies in Python's core design philosophy: **code readability and simplicity**. When Guido created Python, he had a vision of a language that would be as easy to read as English, where the structure of your code would be immediately apparent just by looking at it. This might not sound revolutionary, but consider this: most programming languages at the time required lots of cryptic symbols, complex syntax, and deep technical knowledge just to write a simple program.
#
# Python changed that. Here's the same task in two different languages:
#
# **Java (a more verbose language):**
#
# ```java
# public class HelloWorld {
#     public static void main(String[] args) {
#         System.out.println("Hello, World!");
#     }
# }
# ```
#
# **Python:**
#
# ```python
# print("Hello, World!")
# ```
#
# See the difference? Python strips away the unnecessary complexity and lets you focus on what you actually want to accomplish. This philosophy of simplicity and readability is woven into every aspect of Python, from its syntax to its community culture.

# %% [markdown]
# #### What Does "High-Level, Interpreted Language" Actually Mean?
#
# You'll often hear Python described as a *high-level, interpreted language* that supports multiple programming aradigms. Let's unpack what that means in practical terms, because these characteristics directly affect how you'll work with Python:
#
# - High level
# - Interpreted
# - Multiple paradigms

# %% [markdown]
# ##### **High-Level:** *Python Handles the Complicated Stuff*
#
# Imagine you're building a house. In a *"low-level"* approach, you'd need to understand the chemistry of concrete, the metallurgy of steel beams, and the physics of load distribution. In a *"high-level"* approach, you work with pre-made materials and tools designed for builders.
#
# Python is *"high-level"* in the same way. It abstracts away (hides) the complex, technical details of how computers actually work:
#
# * You don't need to manually allocate and free memory (the computer's working space)
# * You don't need to understand binary code or processor instructions
# * You don't need to manage how data is stored in memory
#
# Instead, Python provides you with intuitive tools and concepts that map to how humans naturally think about problems. Want to store a list of names? Just create a list. Need to repeat something 10 times? Write a simple loop. Python handles all the underlying complexity for you.
#
# *Why does this matter for you?* It means you can start being productive much faster. While someone learning `C++` might spend weeks understanding memory management before building anything useful, you can start solving real problems with Python in hours or days.

# %% [markdown]
# ##### **Interpreted:** *Run Code Immediately, No Waiting*
#
# When you write Python code, something called the Python interpreter reads and executes your code line by line, in real-time. This is fundamentally different from "compiled" languages like C++ or Java.
#
# Here's the difference in workflow:
#
# **Compiled Language Workflow:**
#
# 1. Write code
# 2. Run a compiler to translate your entire program into machine code
# 3. If there are errors, go back to step 1
# 4. If successful, run the compiled program
# 5. If you find a bug or want to make changes, go back to step 1
#
# Interpreted Language Workflow (Python):
#
# 1. Write code
# 2. Run it immediately
# 3. See results instantly
# 4. Make changes and run again
#
# For learning, this is incredibly valuable. You can experiment, test ideas, and see immediate feedback. Made a mistake? No problem—fix it and try again in seconds. This tight feedback loop accelerates learning and makes programming feel more like a conversation with the computer rather than a formal, lengthy process.
#
# > **Real-World Note:** You might hear that interpreted languages are *"slower"* than compiled languages, and there's some truth to that. However, for the vast majority of applications, including **professional data science**, **web development**, and **automation**, Python is more than fast enough. Companies like Google, Netflix, and NASA use Python extensively in production systems (you can read more [here](https://jaydevs.com/top-companies-that-use-python/)). Speed is rarely the bottleneck; developer productivity and code maintainability usually matter much more.

# %% [markdown]
# ##### **Multiple Programming Paradigms:** Flexibility in How You Think
#
# Python supports different *"paradigms"* or styles of programming. Think of paradigms as different ways of organizing and thinking about your code. As a beginner, you don't need to master all of these, you'll naturally gravitate toward what makes sense for your problems. But it's helpful to know they exist:
#
# **1. Procedural Programming:** Write your code as a series of step-by-step instructions, like following a recipe. This is often the most intuitive way to start:
#
# ```python
# # Step 1: Get ingredients
# eggs = 3
# flour = "2 cups"
#
# # Step 2: Mix them
# mixture = mix(eggs, flour)
#
# # Step 3: Bake
# cake = bake(mixture)
# ```
#
# **2. Object-Oriented Programming (OOP):** Organize code around "objects" that combine data and behaviors. This maps well to real-world concepts:
#
# ```python
# # Create a Dog object with properties and behaviors
# my_dog = Dog(name="Lotte", age=11)
# my_dog.bark()  # The dog knows how to bark
# my_dog.fetch(ball)  # The dog knows how to fetch
# ```
#
# **3. Functional Programming:** Treat your code like mathematical functions—given the same inputs, you always get the same outputs:
#
# ```python
# # Pure function: same input always produces same output
# def calculate_tax(income):
#     return income * 0.25
# ```

# %% [markdown]
# The beauty of Python is that you can **mix and match** these approaches. Start with simple procedural code, add some object-oriented concepts when modeling real-world entities, and use functional techniques when they make your code cleaner. Python doesn't force you into any single way of thinking.

# %% [markdown]
# ### 🧩 Important Components: *Stuff that makes the Python Ecosystem*
#
# Now that you understand what Python is, let's explore the key components and concepts you'll encounter throughout your Python journey. Think of this as learning the vocabulary and landscape before you start traveling.

# %% [markdown]
# #### The Zen of Python: *Python's Guiding Philosophy*
#
# Python isn't just a programming language—it's a philosophy about how code should be written. This philosophy is captured in "The Zen of Python", a collection of 19 guiding principles written by Tim Peters. These aren't strict rules, but rather wisdom accumulated from decades of programming experience.
#
# As introduced in the previous chapter, you can read the full Zen of Python anytime by opening a Python interpreter and typing import this. Here are some of the most important principles:
#
# > "Beautiful is better than ugly"
#
# Code isn't just for computers, it's primarily for humans to read and understand. Python encourages you to write code that is elegant and pleasant to look at.
#
# > "Explicit is better than implicit"
#
# Your code should clearly express what it's doing. Avoid clever tricks that obscure meaning. Other people (including future you) should be able to understand your code without playing detective.
#
# > "Simple is better than complex"
#
# If you can solve a problem with a simple solution, do it. Don't add complexity unless it's absolutely necessary.
#
# > "Readability counts"
#
# This is perhaps Python's most important principle. Your code will be read many more times than it's written. Make it easy to read.
#
# > "There should be one—and preferably only one—obvious way to do it"
#
# Unlike some languages that offer multiple ways to accomplish the same task, Python typically provides one clear, "Pythonic" way. This makes Python code more consistent and predictable across different projects and developers.
#
# *Why should you care about the Zen of Python?* As you learn, you'll face choices about how to structure your code. The Zen of Python provides a compass for those decisions. When you're unsure whether your code is *"good"*, ask yourself: Is it simple? Is it readable? Is it explicit? If yes, you're on the right track.

# %% [markdown]
# #### Python Versions: *Understanding 2 vs. 3*
#
# When you start exploring Python resources online, you'll inevitably encounter references to **"Python 2"** and **"Python 3"**. Here's what you need to know:
#
# * **Python 2 (Legacy):**
#     * Released in 2000
#     * Officially discontinued on January 1, 2020
#     * Still appears in old tutorials, legacy codebases, and some embedded systems
#     * You should not learn or use Python 2 as a beginner
#
# * **Python 3 (Current):**
#     * First released in 2008
#     * Not fully backward-compatible with Python 2 (intentional design decision)
#     * The present and future of Python
#     * Continuously updated with new features and improvements
#     * This is what we use in this course
#
# The transition from Python 2 to Python 3 was a significant event in Python's history. The Python team made some important improvements that required breaking backward compatibility, meaning Python 3 code doesn't always work in Python 2 and vice versa. This caused years of fragmentation in the Python community, but we're now **firmly** in the Python 3 era.
#
# *Why am I telling you this?* Because you'll may references to *"Python 2 vs 3"* in older tutorials, Stack Overflow answers, and documentation. Don't let this confuse you. If you're starting in 2025 or later, **Python 3** is your only concern. If you encounter a tutorial that mentions Python 2, it's probably outdated.

# %% [markdown]
# #### The Python Interpreter: *Your Code Translator*
#
# When you write Python code, you're writing in a language humans can (hopefully) understand. But computers don't speak Python, they speak machine code (aka binary instructions). Something needs to translate between these two worlds, and that's where the Python interpreter comes in.
#
# Think of the interpreter as a simultaneous translator at the United Nations. As you speak (or write Python code), the translator immediately converts your words into a language the other party understands (machine code), allowing real-time communication.
#
# The standard Python interpreter is called *CPython* (because it's written in the C programming language). When you downloaded Python in the first course unit, you almost certainly installed [CPython](https://en.wikipedia.org/wiki/CPython). There are alternative interpreters like:
#
# * [PyPy](https://pypy.org/): A faster interpreter for certain types of programs
# * [Jython](https://www.jython.org/): Runs on the Java Virtual Machine
# * [IronPython](https://ironpython.net/): Integrates with Microsoft's .NET framework
#
# For this course, you don't need to worry about which interpreter you're using. They all understand Python code, and the differences mainly matter for much more advanced optimization scenarios. Just know that when you run Python code, an interpreter is working behind the scenes to make it happen.

# %% [markdown]
# #### Package Management: *Standing on the Shoulders of Giants*
#
# One of Python's greatest strengths is its **ecosystem of libraries** (also called `packages` or `modules`). A library is simply a collection of pre-written code that solves specific problems. Instead of writing everything from scratch, you can use libraries to:
#
# * Analyze data (pandas, NumPy) *--> covered in Units 04 and 05*
# * Create visualizations (Matplotlib, Seaborn) *--> covered in Unit 06*
# * Perform machine learning (scikit-learn, TensorFlow) *--> covered in Unit 07*
# * Build websites (Django, Flask)
# * And thousands of other tasks...
#
# But how do you find, install, and manage these libraries? That's where package managers come in:
#
# * [pip](https://pip.pypa.io/en/stable/) (Python Package Installer):
#     * The default package manager for Python
#     * Comes pre-installed with Python 3.4+
#     * Used to install packages from the Python Package Index (PyPI), a repository of over 400,000 packages
#     * Simple command: ```pip install package_name```
# * [conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/index.html):
#     * Package manager from Anaconda
#     * Manages both Python packages and non-Python dependencies
#     * Particularly popular in data science
#     * Also manages virtual environments
#
# *You've already worked with these tools in [Unit 1](https://github.com/nikolaiwest/introduction-to-python/blob/main/chapters/unit-01_setup/chapter-00_outline-and-best-practices.ipynb).* If you want to learn more (or re-cap), just visit the [Chapter 3](https://github.com/nikolaiwest/introduction-to-python/blob/main/chapters/unit-01_setup/chapter-03_environments-and-packages.ipynb) of Unit 01 on *Environments and Packages*. Understanding their purpose helps you appreciate why they're important. Without package managers, you'd need to manually download, install, and configure every library you wanted to use, a nightmare of dependency management. Package managers handle all of this automatically.

# %% [markdown]
# ### 📊 Python at a Glance: *A Re-Cap of the Key Characteristics*
#
# Let's consolidate what we've learned into a quick reference table. This gives you a high-level view of Python's key features and what they mean in practice:
#
# | **Feature** | **Description** | **What This Means For You** |
# |-------------|-----------------|------------------------------|
# | **Readability** | Clear syntax with significant whitespace | Your code looks clean and organized; less time deciphering cryptic symbols |
# | **Dynamically Typed** | Variable types determined at runtime | You don't declare types explicitly; Python figures them out (`x = 5` then `x = "hello"` is valid) |
# | **Interpreted** | Code executed line by line | No compilation wait time; instant feedback; easier debugging |
# | **Multi-Paradigm** | Supports different programming styles | Use procedural, object-oriented, or functional approaches—whatever fits your problem |
# | **Cross-Platform** | Runs on Windows, macOS, Linux | Write once, run anywhere; same code works across operating systems |
# | **Extensive Standard Library** | Comes with built-in tools | Many common tasks don't require external packages; Python is "batteries included" |

# %% [markdown]
# ### 📘 Main Content
#
# #### Key Features of Python
#
# Python's popularity stems from several key features that make it both powerful and approachable:
#
# * **Easy to Learn and Read**: Python's syntax is clear and intuitive, resembling English in many ways, which reduces the learning curve for beginners.
#
#    ```python
#    # Python code is often self-explanatory
#    names = ["Alice", "Bob", "Charlie"]
#    for name in names:
#       print(f"Hello, {name}!")
#    ```
#
# * **Dynamically Typed**: You don't need to declare variable types explicitly; Python infers them based on the assigned values.
#
#    ```python
#    # No type declarations needed
#    count = 10          # An integer
#    message = "Hello"   # A string
#    price = 9.99        # A float
#    ```
#
# * **Interpreted Language**: No separate compilation step is needed; code is executed line by line.
#
# * **Extensive Standard Library**: Python comes with a large library of modules that provide ready-to-use functionality for various tasks.
#
# * **Large and Active Community**: A vast community contributes to Python's ecosystem, creating libraries, frameworks, and resources for learners.
#
# #### ⚠️ Common Misconceptions About Python
#
# - **Python is only for beginners**: While Python is excellent for beginners, it's also used for complex, production-scale applications in major tech companies.
# - **Python is too slow for real applications**: While Python may be slower than compiled languages for certain tasks, it's more than fast enough for most applications, and performance-critical parts can be optimized.
# - **Python is only for data science and web development**: Python is used in diverse fields including *game development*, *embedded systems*, *desktop applications*, and more.
#
# #### 🔄 Quick Check: Python Fundamentals
#
# Which of the following is **NOT** one of Python's key features?
#
# 1. Dynamically typed
# 2. Compiled language
# 3. Cross-platform compatibility
# 4. Extensive standard library
#
# <details>
#    <summary>View Answer</summary>
#
#    The answer is **2. Compiled language**. Python is an interpreted language, meaning it executes code line by line without a separate compilation step. The other options (*dynamically typed*, *cross-platform*, and *extensive standard library*) are all key features of Python.
# </details>
#
# #### Python's Versatility
#
# Python's rich ecosystem of libraries and frameworks makes it a powerful tool for a wide range of applications. Here are some key areas where Python excels, along with popular libraries for each:
#
# ##### 1. Web Development
# Python offers several frameworks for building web applications and services:
#
# - **Django**: A high-level web framework for rapid development with clean, pragmatic design. It follows the *"batteries-included"* philosophy, providing many built-in features.
# - **Flask**: A lightweight, flexible micro-framework for building web applications with minimal boilerplate code.
# - **FastAPI**: A modern, fast framework for building APIs with Python 3.6+, leveraging type hints for validation and documentation.
#
#    ```python
#    # Simple Flask application example
#    from flask import Flask
#    app = Flask(__name__)
#
#    @app.route('/')
#    def hello_world():
#       return 'Hello, World!'
#
#    # Don't worry too much about the @ in the syntax for now.
#    # If you want to learn more about callbacks, take a look at unit 03 chapter 02.
#    ```
#
# #### 📚 Further Reading: Python Fundamentals
#
# - [The Zen of Python](https://peps.python.org/pep-0020/) - Python's guiding principles
# - [Python's History](https://en.wikipedia.org/wiki/History_of_Python) - The evolution of Python
# - [Python Success Stories](https://www.python.org/about/success/) - Real-world applications
#
# ##### 2. Data Analysis and Visualization
# Python has become the language of choice for data scientists and analysts:
#
# * **NumPy**: Fundamental package for scientific computing with support for large, multi-dimensional arrays and matrices.
#
# * **Pandas**: Data manipulation and analysis library, providing data structures like DataFrames for efficiently handling structured data.
#
# * **Matplotlib**: A comprehensive library for creating static, animated, and interactive visualizations.
#
#    ```python
#    # Simple data visualization with matplotlib
#    import matplotlib.pyplot as plt
#    import numpy as np
#
#    x = np.linspace(0, 10, 100)
#    y = np.sin(x)
#    plt.plot(x, y)
#    plt.title('Sine Wave')
#    plt.show()
#
#    # Matplotlib is a major library for visualization with python.
#    # We will explore it in detail in unit 06.
#    ```
#
# #### 🔄 Quick Check: Python Libraries
#
# Which Python library would be most appropriate for analyzing a large dataset of financial transactions?
#
# 1. Django
# 2. Pygame
# 3. Pandas
# 4. Flask
#
# <details>
#    <summary>View Answer</summary>
#
#    The answer is 3. Pandas. Pandas is specifically designed for data manipulation and analysis, making it ideal for working with structured data like financial transactions. Django and Flask are web frameworks, while Pygame is for game development.
# </details>
#
# ##### 3. Machine Learning and Artificial Intelligence
# Python leads the field in ML and AI development:
#
# * **TensorFlow**: An open-source platform for machine learning developed by Google.
#
# * **PyTorch**: An open-source machine learning library developed by Facebook's AI Research lab.
#
# * **Scikit-learn**: Machine learning library featuring various classification, regression, and clustering algorithms.
#
# ##### 4. Additional Domains
# Python's versatility extends to many other fields:
#
# * **Image Processing**: Pillow, OpenCV-Python
# * **Natural Language Processing**: NLTK, SpaCy
# * **Web Scraping**: Beautiful Soup, Scrapy
# * **Game Development**: Pygame, Panda3D
# * **Network Programming**: Twisted, Scapy
# * **GUI Development**: Tkinter, PyQt, Kivy
# * **Automation and Scripting**: Ansible, Fabric
# * **Cybersecurity**: Requests, Paramiko
#
# #### 📚 Further Reading: Python Ecosystem
#
# * [Python Package Index (PyPI)](https://pypi.org/) - The repository of Python packages
# * [Awesome Python](https://github.com/vinta/awesome-python) - A curated list of Python frameworks, libraries, and resources
# * [Real Python Tutorials](https://realpython.com/) - Practical Python programming tutorials
#
# [⬆️ Back to the Top](#ue2-syntax)
#
# ---

# %% [markdown]
# ## **Chapter 1.2:** Setting Up An Environment
#
# ### 🔍 Installing Python
#
# To start coding in Python, you first need to ensure Python is properly installed on your system. Although we covered this in Unit 1, here's a quick recap for different operating systems:
#
# #### Windows:
# 1. Visit [python.org](https://www.python.org/downloads/) and download the latest version for Windows
# 2. Run the installer, ensuring you check the box that says "**Add Python to PATH**"
# 3. Verify installation by opening Command Prompt and typing:
#    ```cmd
#    python --version
#    ```
#
# #### macOS:
# 1. Install Homebrew if not already installed:
#    ```bash
#    /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#    ```
# 2. Install Python using Homebrew:
#    ```bash
#    brew install python
#    ```
# 3. Verify installation by opening Terminal and typing:
#    ```bash
#    python3 --version
#    ```
#
# #### Linux:
# 1. Most Linux distributions come with Python pre-installed
# 2. To install the latest version, use your distribution's package manager, for example, on Ubuntu:
#    ```bash
#    sudo apt-get update && sudo apt-get install python3
#    ```
# 3. Verify with:
#    ```bash
#    python3 --version
#    ```
#
# ### 🧩 Important Components
#
# * **Python Interpreter**: The core component that executes Python code. When you install Python, this is what's running when you type `python` in your terminal.
#
# * **Standard Library**: Included with Python installation, providing modules for common tasks like file I/O, system interaction, and data structures.
#
# * **pip**: The package installer for Python, used to install and manage additional packages from the Python Package Index (PyPI).
#
# * **Development Environment**: The tools you use to write, test, and debug your Python code (IDE or text editor).
#
# * **Virtual Environment**: A self-contained directory containing a Python installation and packages, allowing isolated project dependencies.
#
# | Tool Type | Examples | Best For |
# |-----------|----------|----------|
# | Text Editors | VS Code, Sublime Text, Atom | Lightweight editing, versatility |
# | IDEs | PyCharm, Spyder, Wing | Full-featured development, debugging |
# | Notebooks | Jupyter, Google Colab | Interactive computing, data analysis |
# | Online Platforms | Replit, PythonAnywhere | Quick experimentation, sharing |
#
# ### 📘 Main Content
#
# #### Choosing an IDE or Text Editor
#
# Having the right development environment can significantly enhance your productivity and learning experience. Here are some popular options:
#
# ##### Jupyter Notebook
# - **Best for**: Data science, exploratory coding, and sharing work with visualizations
# - **Features**: Interactive cells, in-line visualizations, markdown support
# - **Installation**: `pip install notebook`, then run with `jupyter notebook`

# %%
# This code should be in a Jupyter Notebook cell
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.title("A Simple Sine Wave")

# The visualization is just a test for now, we will explore this in the future in more detail (see unit 06).

# %% [markdown]
# ##### Visual Studio Code
# - **Best for**: General-purpose development, larger projects
# - **Features**: Lightweight, extensible, excellent Python support through extensions
# - **Installation**: Download from [code.visualstudio.com](https://code.visualstudio.com/)
# - **Key extensions**: Python, Pylance, Jupyter
#
# #### ⚠️ Common Environment Setup Issues
#
# * **PATH problems**: If `python` command isn't recognized, your PATH may not be set correctly
# * **Permission errors**: On Unix systems, you might need to use `sudo` for system-wide installations
# * **Multiple Python versions**: Having multiple versions can lead to confusion about which one is being used
#
# #### 🔄 Quick Check: Development Environment
#
# Which of the following is NOT typically used for Python development?
#
# 1. Visual Studio Code
# 2. Jupyter Notebook
# 3. Adobe Photoshop
# 4. PyCharm
#
# <details>
#    <summary>View Answer</summary>
#
#    The answer is 3. Adobe Photoshop. Photoshop is an image editing software, not a development environment for Python. All the other options (Visual Studio Code, Jupyter Notebook, and PyCharm) are commonly used for Python development.
# </details>
#
# #### Virtual Environments
#
# Virtual environments allow you to create isolated Python environments for different projects. This helps manage dependencies and avoid conflicts between project requirements.
#
# ##### Creating a Virtual Environment
#
# 1. Open your terminal or command prompt
# 2. Navigate to your project directory
# 3. Create a new virtual environment:
#    ```bash
#    python -m venv myenv
#    ```
#
# ##### Activating the Environment
#
# Different operating systems have different activation commands:
#
# - **Windows**:
#   ```cmd
#   myenv\Scripts\activate
#   ```
#
# - **macOS/Linux**:
#   ```bash
#   source myenv/bin/activate
#   ```
#
# When activated, you'll see the environment name in your prompt, e.g., `(myenv)`.
#
# #### ⚠️ Common Virtual Environment Mistakes
#
# * **Forgetting to activate**: Always activate your virtual environment before installing packages or running your project
# * **Installing packages globally**: Avoid using `pip install` without activating a virtual environment first
# * **Committing environment files**: Don't include the virtual environment directory in version control (use `.gitignore`)
#
# #### 🔄 Quick Check: Virtual Environments
#
# What is the primary purpose of using virtual environments in Python?
#
# <details>
#    <summary>View Answer</summary>
#
#    The primary purpose of virtual environments is to create isolated environments for different Python projects. This prevents dependency conflicts, as each project can have its own set of packages with specific versions, without interfering with other projects or the system-wide Python installation.
# </details>
#
# #### 📚 Further Reading: Python Environment Setup
#
# * [Python Virtual Environments: A Primer](https://realpython.com/python-virtual-environments-a-primer/)
# * [VS Code Python Tutorial](https://code.visualstudio.com/docs/python/python-tutorial)
# * [Jupyter Notebook Documentation](https://jupyter-notebook.readthedocs.io/en/stable/)
#
# [⬆️ Back to the Top](#ue2-syntax)
#
# ---

# %% [markdown]
# ## **Chapter 1.3:** Your First Python Program
#
# ### 🔍 Writing and Running Your First Program
#
# Now that your environment is set up, let's write your first Python program: the classic "Hello, World!". We'll explore different methods for writing and running Python code.
#
# ### 🧩 Important Components
#
# * **Python Script**: A file with a `.py` extension containing Python code that can be executed.
#
# * **print() Function**: A built-in function that displays output to the console.
#
# * **String Literals**: Text enclosed in quotation marks (either single `'` or double `"`).
#
# * **Comments**: Notes in the code (preceded by `#`) that the interpreter ignores.
#
# * **Interactive Mode**: A command-line interface where Python commands are executed immediately.
#
# | Method | File Extension | Best For |
# |--------|---------------|----------|
# | Script Files | .py | Reusable programs, larger projects |
# | Jupyter Notebooks | .ipynb | Interactive analysis, visualization, documentation |
# | Interactive Mode | N/A | Quick testing, learning, experimentation |
#
# ### 📘 Main Content
#
# #### Method 1: Using a `.py` File
#
# Python code is typically saved in files with a `.py` extension. Here's how to create and run a simple Python script:
#
# 1. **Creating the Python File**:
#    - Open your chosen text editor or IDE
#    - Create a new file and save it as `hello_world.py`
#    - Type the following code:
#
#      ```python
#      # My first Python program
#      print("Hello, World!")
#      ```
#
#    - Save the file
#
# 2. **Running the Python File**:
#    - Open your terminal or command prompt
#    - Navigate to the directory containing your script using the `cd` command
#    - Run the script:
#
#      ```cmd
#      python hello_world.py
#      ```
#
#    - You should see `Hello, World!` printed in the console
#
# #### ⚠️ Common Mistakes When Running Scripts
#
# * **File not found errors**: Make sure you're in the correct directory when running the script
# * **Permission issues**: On Unix systems, you might need to make the script executable with `chmod +x filename.py`
# * **Python not recognized**: Ensure Python is properly installed and added to your PATH
#
# #### 🔄 Quick Check: Running Python Scripts
#
# If you save a file named `greetings.py` with the code `print("Hi there!")`, what command would you use to run it from the terminal?
#
# <details>
#    <summary>View Answer</summary>
#
#    The command would be `python greetings.py` (or `python3 greetings.py` on some systems). This tells the Python interpreter to execute the code in the greetings.py file.
# </details>
#
# #### Method 2: Using a Jupyter Notebook
#
# Jupyter Notebooks provide an interactive environment that combines code, output, and documentation:
#
# 1. **Starting Jupyter Notebook**:
#    - Open your terminal or command prompt
#    - Navigate to your desired directory
#    - Run:
#      ```bash
#      jupyter notebook
#      ```
#    - This launches Jupyter in your web browser
#
# 2. **Creating a New Notebook**:
#    - Click "New" → "Python 3" to create a new notebook
#    - Rename it by clicking on "Untitled" at the top
#
# 3. **Writing and Running Code**:
#    - In a code cell, type:
#      ```python
#      print("Hello, World!")
#      ```
#    - Run the cell by pressing Shift+Enter or clicking the "Run" button
#    - The output appears below the cell
#
# #### Understanding the Code
#
# Let's break down our simple "Hello, World!" program:

# %%
print("Hello, World!")

# %% [markdown]
# - `print()` is a **built-in function** in Python that displays text output to the console
# - `"Hello, World!"` is a **string**, which is a sequence of characters enclosed in quotation marks
# - The parentheses `()` are used to pass arguments to functions
# - The statement ends without a semicolon, unlike many other programming languages
#
# This simple program demonstrates several Python characteristics:
# - Simplicity and readability
# - No need for complex setup or boilerplate code
# - Direct function calling syntax
#
# #### 📚 Further Reading: Python Basics
#
# * [Official Python Tutorial](https://docs.python.org/3/tutorial/index.html)
# * [Learn Python in 10 Minutes](https://www.stavros.io/tutorials/python/)
# * [Automate the Boring Stuff with Python](https://automatetheboringstuff.com/)
#
# #### Python's Interactive Mode
#
# Python also offers an interactive mode where you can execute code line by line:
#
# 1. **Launching Interactive Mode**:
#    - Open your terminal or command prompt
#    - Type `python` or `python3` and press Enter
#    - You'll see the Python prompt `>>>`
#
# 2. **Executing Commands**:
#    - At the prompt, type:
#      ```python
#      >>> print("Hello, World!")
#      ```
#    - Press Enter to execute the command
#    - You'll see the output immediately:
#      ```
#      Hello, World!
#      ```
#
# 3. **Experimenting with Python**:
#    - Try simple calculations:
#      ```python
#      >>> 2 + 3
#      5
#      >>> 10 / 2
#      5.0
#      ```
#    - Define variables:
#      ```python
#      >>> name = "Python"
#      >>> print("Hello, " + name + "!")
#      Hello, Python!
#      ```
#
# #### ⚠️ Common Beginner Mistakes
#
# * **Forgetting quotation marks** around strings
# * **Incorrect indentation**, which is significant in Python
# * **Mixing tabs and spaces** for indentation (stick to one, preferably spaces)
# * **Case sensitivity issues** - Python distinguishes between uppercase and lowercase
#
# #### 🔄 Quick Check: Python Interactive Mode
#
# In Python's interactive mode, what would be the output of the following commands?
#
# ```python
# >>> x = 5
# >>> y = 2
# >>> x * y
# ```
#
# <details>
#    <summary>View Answer</summary>
#
#    The output would be `10`. The expression `x * y` multiplies the values of x (5) and y (2), resulting in 10. In interactive mode, expressions are evaluated and their results are displayed automatically.
# </details>
#
# [⬆️ Back to the Top](#ue2-syntax)
#
# ---

# %% [markdown]
# ## 👨‍💻 **Practice Tasks 1.3:** Your First Python Program
#
# Now it's your turn to write some Python code! Complete the following tasks using your preferred method (Python file, Jupyter Notebook, or interactive mode):
#
# **Creating Your First Script:**
# 1. Write a Python script that prints `"Hello, [Your Name]!"` replacing `[Your Name]` with your actual name.

# %%
# 1. Write a Python script that prints "Hello, [Your Name]!"
print("Hello, Marco!")

# %% [markdown]
# **Working with Multiple Outputs:**
# 2. Modify the script to print two separate lines: "Hello!" on the first line and your name on the second line.

# %%
# 2. Modify the script to print two separate lines
print("Hello!")
print("Marco")

# %% [markdown]
# **Adding Comments:**
# 3. Add a comment above your code explaining what the script does using the `#` symbol.

# %%
# 3. Add a comment above your code explaining what the script does
# This script prints a greeting followed by my name on a separate line
print("Hello!")
print("Marco")

# %% [markdown]
# **Basic Calculations:**
# 4. Create a new script that performs and prints the result of three different arithmetic operations (addition, multiplication, division).

# %%
# 4. Create a script with three arithmetic operations
print(10 + 5)  # Addition
print(10 * 5)  # Multiplication
print(10 / 5)  # Division

# %% [markdown]
# [⬆️ Back to the Top](#ue2-syntax)
#
# ---

# %% [markdown]
# ## 📋 Chapter Summary
#
# - Python is a versatile, high-level, interpreted programming language known for its readability and ease of use
# - Python supports multiple programming paradigms including procedural, object-oriented, and functional programming
# - Python's extensive ecosystem of libraries and frameworks makes it suitable for a wide range of applications, from web development to data science and AI
# - A proper development environment consists of Python itself, a suitable IDE or text editor, and virtual environments for project isolation
# - Python code can be written and executed in several ways: as `.py` files, in Jupyter Notebooks, or through the interactive mode
# - The simplest Python program can be just a single line, like `print("Hello, World!")`
# - Python's syntax is designed to be intuitive and readable, with significant whitespace and minimal punctuation
#
# ## 🔮 Looking Ahead
#
# In the next chapter, we'll dive deeper into Python basics, exploring fundamental concepts like variables, data types, operators, and strings. You'll learn how to store and manipulate different kinds of data, perform calculations, and work with text. These core concepts form the building blocks of Python programming that you'll use in virtually every program you write.
#
# ## 📚 Key Terms
#
# - **Python**: A high-level, interpreted programming language known for its readability and versatility
# - **Interpreter**: A program that executes code line by line without requiring compilation first
# - **IDE**: Integrated Development Environment, a software application that provides comprehensive facilities for software development
# - **Virtual Environment**: An isolated Python environment that allows projects to have their own dependencies
# - **Script**: A Python file (with `.py` extension) containing code to be executed
# - **Jupyter Notebook**: An interactive computing environment that allows you to combine code execution, rich text, and visualizations
# - **Interactive Mode**: A way of running Python commands line by line with immediate feedback
# - **Function**: A reusable block of code that performs a specific task, like `print()`
# - **String**: A sequence of characters enclosed in quotation marks
#
# ## 🔍 Further Exploration
#
# For those interested in diving deeper into Python fundamentals:
#
# - Try other simple Python programs, like basic calculations or manipulating different strings
# - Explore Python's built-in functions by typing `help()` in interactive mode
# - Watch video tutorials about Python basics on platforms like YouTube or Coursera
# - Read the official Python tutorial in the [Python documentation](https://docs.python.org/3/tutorial/)
# - Join coding communities like Stack Overflow or Reddit's r/learnpython to connect with other learners
#
# [⬆️ Back to the Top](#ue2-syntax)
#
# ---
