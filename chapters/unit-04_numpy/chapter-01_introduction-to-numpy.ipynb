# %% [markdown]
# # **UE4: NumPy**
#
# # **Chapter 01:** Introduction to NumPy
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/NumPy_logo_2020.svg/512px-NumPy_logo_2020.svg.png" height="150">
#
# ## 🌟 Introduction
#
# Welcome to the world of **NumPy**, the fundamental package for scientific computing in Python. NumPy introduces a powerful **array object** that revolutionizes how you work with numerical data, making operations more efficient and your code more concise and readable.
#
# In scientific and data-driven fields, working with large datasets and performing complex numerical operations is the norm. Python's built-in lists and mathematics capabilities are *insufficient* for such tasks, both in terms of performance and functionality. NumPy bridges this gap, offering a robust foundation for virtually all numerical computations in Python.
#
# > **Tip:** While NumPy may seem like just another library, it's actually the foundation of the entire scientific Python ecosystem. Mastering NumPy will make learning other data science libraries like Pandas, Matplotlib, and Scikit-learn much easier.
#
# ## 📚 Chapter Outline
#
# ### [Chapter 1.1: Overview of NumPy](#chapter-11-overview-of-numpy)
# - **[Understanding the Need for NumPy:](#-understanding-the-need-for-numpy)** Why Python's built-in types aren't sufficient for scientific computing.
# - **[Core Features and Capabilities:](#-core-features-and-capabilities)** Introduction to NumPy's powerful array object and functions.
# - **[NumPy's Role in the Python Ecosystem:](#-numpys-role-in-the-python-ecosystem)** How NumPy connects to other scientific libraries.
#
# ### [Chapter 1.2: Installation and Setup](#chapter-12-installation-and-setup)
# - **[Installing NumPy:](#-installing-numpy)** Methods for installing NumPy on different platforms.
# - **[Verifying the Installation:](#-verifying-the-installation)** Ensuring NumPy is properly installed.
# - **[Importing NumPy:](#-importing-numpy)** Proper conventions for importing NumPy in your code.
#
# ### [Chapter 1.3: Why NumPy?](#chapter-13-why-numpy)
# - **[Performance Advantages:](#-performance-advantages)** How NumPy outperforms Python lists for numerical operations.
# - **[Memory Efficiency:](#-memory-efficiency)** Understanding NumPy's memory-efficient storage approach.
# - **[Vectorization Benefits:](#-vectorization-benefits)** The power of vectorized operations versus loops.
#
# ## 💡 What You Will Learn
#
# By the end of this chapter, you will be able to:
# - Understand why NumPy is essential for scientific computing and data analysis
# - Install NumPy and set up your environment for numerical computing
# - Explain the key advantages NumPy offers over Python's built-in data structures
# - Recognize how NumPy forms the foundation for the scientific Python ecosystem
# - Begin thinking in terms of array-based computation rather than loops
#
# ---
# ---

# %% [markdown]
# ## **Chapter 1.1:** Overview of NumPy
#
# ### 🔍 Understanding the Need for NumPy
#
# Python has become one of the most popular languages for scientific computing and data analysis. However, Python's built-in data structures and operations weren't initially designed for these purposes. Python lists, while flexible, are **inefficient for numerical operations** because:
#
# 1. They store references to objects, not the objects themselves, adding memory overhead
# 2. They can contain different data types, which prevents optimizations
# 3. Operations on lists often require explicit looping in Python, which is slow
#
# **NumPy** (*Numerical Python*) was developed to address these limitations. It provides a multidimensional array object optimized for numerical operations, as well as a comprehensive library of mathematical functions to operate on these arrays.
#
# ### 🔍 Core Features and Capabilities
#
# At the heart of NumPy is the `ndarray` (N-dimensional array) object, which offers several advantages:
#
# 1. **Homogeneous arrays**: All elements have the same data type, enabling memory efficiency and optimized operations
# 2. **Contiguous memory**: Data is stored in a single, continuous block of memory, improving cache coherence and performance
# 3. **Vectorized operations**: Functions operate on entire arrays, eliminating the need for explicit loops
# 4. **Broadcasting**: Ability to perform operations on arrays of different shapes
#
# Beyond the array object, NumPy provides a rich set of features:
#
# * **Mathematical functions**: From basic arithmetic to advanced linear algebra
# * **Random number generation**: Comprehensive tools for generating random data
# * **Array manipulation**: Functions for reshaping, joining, and splitting arrays
# * **Linear algebra operations**: Matrix multiplication, decomposition, eigenvalues, etc.
# * **Fourier transforms**: Tools for frequency analysis
# * **Integration with C/C++**: Ability to interface with lower-level code for performance
#
# ### 🧩 Important Components
#
# * **ndarray**: The fundamental object in NumPy, representing an N-dimensional array.
# * **Universal functions (ufuncs)**: Fast, element-by-element array operations.
# * **Broadcasting**: Rules that allow operations between arrays of different shapes.
#
# | Feature | Description | Example |
# |---------|-------------|---------|
# | Array creation | Methods to create arrays | `np.array([1, 2, 3])`, `np.zeros((3, 3))` |
# | Array operations | Mathematical functions for arrays | `np.add(a, b)`, `np.sqrt(a)` |
# | Indexing/Slicing | Ways to access array elements | `a[0, 2]`, `a[:, 1:3]` |
# | Linear algebra | Matrix operations | `np.dot(a, b)`, `np.linalg.inv(a)` |

# %% [markdown]
# ### 📘 Main Content
#
# #### NumPy: Numerical Computing with Python
#
# NumPy (short for Numerical Python) is an open-source library that provides a powerful array object and a collection of functions for working with these arrays. It forms the foundation of the scientific Python ecosystem and is used in virtually every scientific and engineering discipline.
#
# Let's start by importing NumPy and creating our first array:

# %%
import numpy as np  # Standard convention for importing NumPy

# Create a simple array
arr = np.array([1, 2, 3, 4, 5])
print(arr)          # Output: [1 2 3 4 5]
print(type(arr))    # Output: <class 'numpy.ndarray'>

# %% [markdown]
# This simple example already shows how NumPy differs from regular Python lists. The output format is different, and the type is `numpy.ndarray` instead of `list`.
#
# #### The ndarray Object
#
# The `ndarray` (N-dimensional array) is the primary object in NumPy. It's a homogeneous array of fixed-size items, usually numbers. The number of dimensions and items in an array is defined by its shape. For example, a vector has shape (n,), a matrix has shape (n, m), and so on.

# %%
# Different types of arrays
scalar = np.array(42)                       # 0D array (scalar)
vector = np.array([1, 2, 3])                # 1D array (vector)
matrix = np.array([[1, 2, 3], [4, 5, 6]])   # 2D array (matrix)
tensor = np.array([[[1, 2], [3, 4]],
                  [[5, 6], [7, 8]]])        # 3D array (tensor)

# Examining the properties
print(f"Scalar shape: {scalar.shape}")      # ()
print(f"Vector shape: {vector.shape}")      # (3,)
print(f"Matrix shape: {matrix.shape}")      # (2, 3)
print(f"Tensor shape: {tensor.shape}")      # (2, 2, 2)

# %% [markdown]
# The power of NumPy becomes evident when we perform operations on these arrays. Instead of writing loops, we can operate on entire arrays at once:

# %%
# Array-wise operations
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# Addition
print(a + b)  # Output: [5 7 9]

# Multiplication
print(a * b)  # Output: [4 10 18] (element-wise multiplication)

# Squaring each element
print(a ** 2)  # Output: [1 4 9]

# %% [markdown]
# #### NumPy's Role in the Python Ecosystem
#
# NumPy doesn't exist in isolation. It forms the foundation for a rich ecosystem of scientific Python libraries:
#
# * **Pandas**: Built on NumPy, adds data structures for data analysis
# * **Matplotlib**: Visualization library that works well with NumPy arrays
# * **SciPy**: Scientific computing library that extends NumPy's capabilities
# * **Scikit-learn**: Machine learning library that relies on NumPy arrays
# * **TensorFlow/PyTorch**: Deep learning frameworks that interface with NumPy
#
# This ecosystem is often referred to as the "SciPy stack," with NumPy serving as its foundation.
#
# #### ⚠️ Common Mistakes with NumPy
#
# * **Forgetting to import NumPy**: Always include `import numpy as np` at the top of your script.
# * **Mixing NumPy arrays with Python lists**: This can lead to unexpected behavior and reduced performance.
# * **Using loops instead of vectorized operations**: This defeats the purpose of NumPy's efficiency.
#
# #### 🔄 Quick Check: Understanding NumPy
#
# What would be the output of the following code?
#
# ```python
# import numpy as np
#
# a = np.array([1, 2, 3])
# b = [1, 2, 3]
#
# print(a * 2)
# print(b * 2)
# ```
#
# <details>
#    <summary>View Answer</summary>
#
#    The output would be:
#    ```
#    [2 4 6]
#    [1, 2, 3, 1, 2, 3]
#    ```
#
#    This demonstrates a key difference between NumPy arrays and Python lists. When multiplying a NumPy array by a scalar, it performs element-wise multiplication. When multiplying a Python list by a scalar, it repeats the list that many times.
# </details>

# %% [markdown]
# #### 📚 Further Reading: NumPy Overview
#
# * [NumPy Documentation](https://numpy.org/doc/stable/) - Official NumPy documentation
# * [NumPy User Guide](https://numpy.org/doc/stable/user/index.html) - Comprehensive user guide
# * [From Python to NumPy](https://www.labri.fr/perso/nrougier/from-python-to-numpy/) - Excellent resource for transitioning from Python to NumPy
#
# ---

# %% [markdown]
# ## **Chapter 1.2:** Installation and Setup
#
# ### 🔍 Installing NumPy
#
# Before you can use NumPy, you need to install it on your system. There are several ways to install NumPy depending on your platform and preferences.
#
# #### Using pip (Python's Package Installer)
#
# The most straightforward way to install NumPy is using pip, Python's package manager:
#
# ```bash
# `pip install numpy`
# ```
#
# For users who have both Python 2 and Python 3 installed, you may need to use:
#
# ```bash
# `pip3 install numpy`
# ```
#
# #### Using Anaconda
#
# If you're using the Anaconda distribution (highly recommended for scientific computing), NumPy is already included. If you need to install it explicitly, you can use:
#
# ```bash
# `conda install numpy`
# ```
#
# #### Installing from Source
#
# For advanced users who may need specific optimizations or the latest development version, you can install NumPy from source:
#
# ```bash
# `git clone https://github.com/numpy/numpy.git`
# `cd numpy`
# `pip install -e .`
# ```
#
# ### 🔍 Verifying the Installation
#
# After installation, it's important to verify that NumPy was installed correctly and is accessible from your Python environment.

# %%
import numpy as np

print(np.__version__)

# %% [markdown]
# If NumPy is installed correctly, this will print the version number without any errors.
#
# ### 🔍 Importing NumPy
#
# The standard convention for importing NumPy is:

# %%
import numpy as np

# %% [markdown]
# This imports the NumPy library and assigns it to the shorter name `np`, making it easier to reference in your code. This convention is widely used in the scientific Python community, and it's recommended to follow it for code readability and consistency.
#
# You can also import specific functions from NumPy:

# %%
from numpy import array, zeros, ones

# %% [markdown]
# However, the more common approach is to import the entire library as `np` and then access functions with the `np.` prefix.
#
# ### 🧩 Important Components
#
# * **pip**: Python's package installer, used to install and manage packages.
# * **conda**: Package manager used by Anaconda, an alternative to pip with additional features.
# * **import**: Python statement used to make code from a module available in the current script.
# * **np**: Standard alias for NumPy when importing.
#
# ### 📘 Main Content
#
# #### Setting Up Your Environment for NumPy
#
# For the best experience with NumPy and scientific computing in Python, it's recommended to set up a **dedicated environment**. This helps manage dependencies and avoids conflicts between packages.
#
# ##### Using Virtual Environments
#
# If you're using pip, you can create a virtual environment:
#
# ```bash
# # Create a virtual environment
# python -m venv numpy_env
#
# # Activate the environment (Windows)
# numpy_env\Scripts\activate
#
# # Activate the environment (macOS/Linux)
# source numpy_env/bin/activate
#
# # Install NumPy
# pip install numpy
# ```
#
# ##### Using Conda Environments
#
# If you're using Anaconda or Miniconda:
#
# ```bash
# # Create a conda environment
# conda create -n numpy_env python=3.9
#
# # Activate the environment
# conda activate numpy_env
#
# # Install NumPy
# conda install numpy
# ```
#
# #### Optimized NumPy Installations
#
# NumPy can be significantly faster when it's built with optimized linear algebra libraries like Intel MKL (Math Kernel Library) or OpenBLAS. Anaconda's NumPy distribution typically includes these optimizations already.
#
# To check if your NumPy installation is using an optimized library:

# %%
import numpy as np
np.__config__.show()

# %% [markdown]
# This will display information about how NumPy was built, including which BLAS (Basic Linear Algebra Subprograms) library it's using.
#
# #### Common Installation Issues
#
# When installing NumPy, you might encounter some common issues:
#
# 1. **Insufficient permissions**: If you're installing system-wide, you might need administrator privileges. Try using `pip install numpy --user` to install for the current user only.
#
# 2. **Build dependencies**: If installing from source, you may need additional compilers and libraries. Check the NumPy documentation for specific requirements.
#
# 3. **Version conflicts**: If you're working in a project with specific version requirements, use virtual environments to manage different versions.
#
# #### ⚠️ Common Mistakes with Installation
#
# * **Not using virtual environments**: This can lead to conflicts between package versions.
# * **Installing with both pip and conda**: This can cause confusion about which package is being used.
# * **Forgetting to upgrade NumPy**: Newer versions often include performance improvements and bug fixes.
#
# #### 🔄 Quick Check: Installation and Imports
#
# Which of the following is the correct way to import NumPy and create an array?
#
# A)
#
# ```python
# import numpy
# array = numpy.array([1, 2, 3])
# ```
#
# B)
#
# ```python
# import np
# array = np.array([1, 2, 3])
# ```
#
# C)
#
# ```python
# import numpy as np
# array = np.array([1, 2, 3])
# ```
#
# D)
#
# ```python
# from numpy import array
# my_array = array([1, 2, 3])
# ```
#
#
# <details>
#    <summary>View Answer</summary>
#
#    The correct answers are C and D.
#
#    C follows the standard convention of importing NumPy as `np`.
#    D is also valid, importing just the array function from NumPy.
#
#    A is valid but not conventionally used because it's more verbose.
#    B is incorrect because there is no module named 'np' - it's an alias we create when importing NumPy.
# </details>

# %% [markdown]
# #### 📚 Further Reading: Installation
#
# * [NumPy Installation Guide](https://numpy.org/install/) - Official installation instructions
# * [Anaconda Documentation](https://docs.anaconda.com/) - Guide to using Anaconda for scientific computing
# * [Python Virtual Environments Primer](https://realpython.com/python-virtual-environments-a-primer/) - Detailed guide on virtual environments
#
# ---

# %% [markdown]
# ## **Chapter 1.3:** Why NumPy?
#
# ### 🔍 Performance Advantages
#
# One of the most compelling reasons to use NumPy is its **superior performance** compared to regular Python for numerical operations. NumPy achieves this performance boost through several mechanisms:
#
# 1. **Optimized C Implementation**: NumPy's core functionality is implemented in well-optimized C code, allowing it to execute operations much faster than equivalent Python code.
#
# 2. **Vectorized Operations**: NumPy enables you to express operations on entire arrays without explicit loops, which are then executed efficiently in compiled code.
#
# 3. **Contiguous Memory**: NumPy arrays store data in contiguous blocks of memory, improving cache efficiency and reducing access time.
#
# Let's compare the performance of NumPy arrays to Python lists for a simple operation:

# %%
import numpy as np
import time

# Create a large Python list and NumPy array
size = 1000000
py_list = list(range(size))
np_array = np.array(py_list)

# Multiply each element by 2 using Python list
start_time = time.time()
py_result = [x * 2 for x in py_list]
py_time = time.time() - start_time

# Multiply each element by 2 using NumPy array
start_time = time.time()
np_result = np_array * 2
np_time = time.time() - start_time

print(f"Python list time: {py_time:.6f} seconds")
print(f"NumPy array time: {np_time:.6f} seconds")
print(f"NumPy is {py_time / np_time:.1f}x faster")

# %% [markdown]
# This code typically shows NumPy is many times faster than Python lists for this operation, with the gap widening as the array size increases.
#
# ### 🔍 Memory Efficiency
#
# NumPy arrays are **more memory-efficient** than Python lists for numerical data:
#
# 1. **Homogeneous Elements**: All elements in a NumPy array have the same data type, allowing for compact storage.
#
# 2. **No Python Object Overhead**: Unlike Python lists, which store references to Python objects, NumPy arrays store the actual values.
#
# 3. **Type-Specific Storage**: NumPy uses the minimum number of bytes needed for the specified data type.
#
# Let's compare the memory usage:

# %%
import numpy as np
import sys

# Create a Python list and a NumPy array
size = 1000000
py_list = list(range(size))
np_array = np.array(py_list)

# Calculate memory usage
py_memory = sys.getsizeof(py_list) + sum(sys.getsizeof(item) for item in py_list)
np_memory = np_array.nbytes

print(f"Python list memory: {py_memory / 1e6:.2f} MB")
print(f"NumPy array memory: {np_memory / 1e6:.2f} MB")
print(f"Memory reduction: {py_memory / np_memory:.1f}x")

# %% [markdown]
# This comparison often shows that NumPy arrays use significantly less memory, especially for large datasets.
#
# ### 🔍 Vectorization Benefits
#
# **Vectorization** is a programming paradigm that performs operations on entire arrays rather than individual elements. The benefits include:
#
# 1. **Cleaner, More Readable Code**: Vectorized operations express computations concisely.
#
# 2. **Fewer Errors**: Without explicit loops, there are fewer opportunities for indexing errors.
#
# 3. **Easier Parallelization**: Vectorized operations can be automatically parallelized by NumPy's underlying implementation.
#
# Consider the difference between calculating the Euclidean distance in standard Python versus NumPy:

# %%
import numpy as np
import math

# Two points in 3D space
p1 = [1, 2, 3]
p2 = [4, 5, 6]

# Python implementation
def py_euclidean_distance(point1, point2):
    squared_sum = 0
    for i in range(len(point1)):
        squared_sum += (point1[i] - point2[i]) ** 2
    return math.sqrt(squared_sum)

# NumPy implementation
def np_euclidean_distance(point1, point2):
    return np.sqrt(np.sum((np.array(point1) - np.array(point2)) ** 2))

# Or even more concisely
def np_euclidean_distance_concise(point1, point2):
    return np.linalg.norm(np.array(point1) - np.array(point2))

print(py_euclidean_distance(p1, p2))
print(np_euclidean_distance(p1, p2))
print(np_euclidean_distance_concise(p1, p2))

# %% [markdown]
# The NumPy implementations are not only faster but also more readable and less error-prone.
#
# ### 🧩 Important Components
#
# | Feature | Python Lists | NumPy Arrays | Advantage |
# |---------|-------------|--------------|-----------|
# | Storage | References to objects | Contiguous memory block | Memory efficiency, faster access |
# | Homogeneity | Can mix types | Same type for all elements | Memory efficiency, optimized operations |
# | Operations | Python loops (slow) | Vectorized C code (fast) | Performance |
# | Functionality | Basic sequence operations | Rich mathematical functions | Scientific computing capabilities |
#
# ### 📘 Main Content
#
# #### NumPy's Impact on Scientific Computing
#
# NumPy has revolutionized scientific computing in Python by providing a foundation that combines the ease of use of Python with the performance of compiled languages like C or Fortran. This combination has made Python a viable alternative to traditional scientific computing languages, contributing to its popularity in fields like:
#
# - Data Science and Machine Learning
# - Physics and Engineering
# - Finance and Economics
# - Bioinformatics and Computational Biology
# - Image Processing and Computer Vision
#
# #### The Ecosystem Built on NumPy
#
# NumPy serves as the foundation for a rich ecosystem of scientific Python libraries:
#
# ```
#                        ┌───────────┐
#                        │   NumPy   │
#                        └─────┬─────┘
#                  ┌─────────┬─┴─┬─────────┐
#          ┌───────┴───────┐ │   │ ┌───────┴───────┐
#          │    Pandas     │ │   │ │  Matplotlib   │
#          └───────────────┘ │   │ └───────────────┘
#                      ┌─────┴───┴─────┐
#                      │    SciPy      │
#                      └───────┬───────┘
#                ┌─────────────┼──────────────┐
#        ┌───────┴───────┐ ┌───┴─────────┐ ┌──┴───────────┐
#        │  Scikit-learn │ │ Scikit-image│ │ StatsModels  │
#        └───────────────┘ └─────────────┘ └──────────────┘
# ```
#
# This ecosystem enables researchers, engineers, and data scientists to solve complex problems efficiently using Python.
#
# #### When to Use NumPy (and When Not To)
#
# **Use NumPy when:**
# - Working with large numerical datasets
# - Performing mathematical operations on arrays of data
# - Needing fast performance for numerical computations
# - Implementing algorithms that operate on vectors, matrices, or tensors
# - Processing and analyzing structured data like time series, images, or signals
#
# **NumPy might not be necessary when:**
# - Working with small datasets where performance isn't critical
# - Dealing primarily with text data or heterogeneous collections
# - Performing simple operations that don't benefit from vectorization
# - Working with data that fits naturally in other structures (e.g., dictionaries for key-value pairs)
#
# #### The Evolution of NumPy
#
# NumPy's history dates back to the late 1990s when Travis Oliphant, among others, began developing packages for numerical computing in Python. These efforts evolved into NumPy, which was released in 2005. Since then, NumPy has undergone continuous improvement, with recent developments focusing on:
#
# - Better support for missing data
# - Improved integration with modern hardware (GPUs, parallel processors)
# - Enhanced interoperability with other libraries and languages
# - Support for larger-than-memory datasets
#
# #### ⚠️ Common Misconceptions about NumPy
#
# * **"NumPy replaces Python lists entirely"**: NumPy arrays and Python lists serve different purposes. Lists are better for general-purpose collections of heterogeneous items.
# * **"NumPy is only useful for mathematics"**: While math is a primary use case, NumPy is valuable anywhere structured numerical data is processed.
# * **"NumPy is difficult to learn"**: The basic concepts of NumPy can be learned quickly, especially if you're familiar with array-based operations from other languages.
#
# #### 🔄 Quick Check: NumPy Benefits
#
# Which statement about NumPy is NOT correct?
#
# A) NumPy arrays use less memory than Python lists for storing numerical data.
# B) NumPy operations are generally faster than equivalent operations with Python lists.
# C) NumPy arrays can store different data types in the same array, just like Python lists.
# D) NumPy provides a wide range of mathematical functions for working with arrays.
#
# <details>
#    <summary>View Answer</summary>
#
#    The incorrect statement is C.
#
#    Unlike Python lists, NumPy arrays are homogeneous, meaning all elements must have the same data type. This constraint allows NumPy to optimize memory usage and performance, but it means NumPy arrays cannot store mixed data types in the same array (unless you use a structured data type or object arrays, which sacrifice some performance benefits).
# </details>
#
# #### 📚 Further Reading: NumPy Benefits
#
# * [Why NumPy Instead of Python Lists](https://www.geeksforgeeks.org/python-lists-vs-numpy-arrays/) - Detailed comparison
# * [From Python to NumPy](https://www.labri.fr/perso/nrougier/from-python-to-numpy/) - Excellent guide on transitioning from Python to NumPy
# * [NumPy Performance Tricks](https://ipython-books.github.io/45-understanding-the-internals-of-numpy-to-avoid-unnecessary-array-copying/) - Advanced tips for getting the most out of NumPy
#
# ---

# %% [markdown]
# ## 📋 Chapter Summary
#
# - **NumPy** is the fundamental package for scientific computing in Python, providing a powerful **array object** and a comprehensive set of mathematical functions.
#
# - The **ndarray** (N-dimensional array) is NumPy's core data structure, offering advantages like **homogeneous elements**, **contiguous memory**, and support for **vectorized operations**.
#
# - NumPy can be installed using **pip** or **conda**, and is typically imported as `np` (e.g., `import numpy as np`).
#
# - NumPy offers significant **performance advantages** over Python lists for numerical operations, often running **10-100x faster** due to its optimized C implementation and vectorized approach.
#
# - NumPy arrays are **memory-efficient**, storing data in contiguous blocks with minimal overhead compared to Python lists.
#
# - **Vectorization** allows operations on entire arrays without explicit loops, resulting in cleaner, faster code that's less prone to errors.
#
# - NumPy forms the foundation of the **scientific Python ecosystem**, serving as the basis for libraries like Pandas, Matplotlib, SciPy, and Scikit-learn.
#
# ## 🔮 Looking Ahead
#
# In the next chapter, we'll dive deeper into **NumPy arrays**, learning how to create, manipulate, and operate on these powerful data structures. You'll discover how to leverage NumPy's array creation functions, understand array attributes, and master indexing and slicing techniques. These skills will form the foundation for all your future work with numerical computing in Python.
#
# ## 📚 Key Terms
#
# - **NumPy**: The fundamental package for scientific computing in Python.
# - **ndarray**: N-dimensional array, the primary object in NumPy.
# - **Vectorization**: The process of converting operations that would normally use loops into array operations.
# - **Broadcasting**: NumPy's ability to perform operations on arrays of different shapes.
# - **Universal Functions (ufuncs)**: Functions that operate element-wise on arrays.
# - **Contiguous Memory**: Storage of data in a continuous block, improving performance.
# - **Homogeneous Array**: An array where all elements have the same data type.
# - **SciPy Stack**: The collection of scientific Python libraries built on NumPy.
#
# ## 🔍 Further Exploration
#
# For those interested in diving deeper into NumPy:
#
# - Explore NumPy's random module for generating various distributions of random numbers
# - Investigate structured arrays for storing heterogeneous data
# - Learn about NumPy's linear algebra capabilities for matrix operations
# - Experiment with NumPy's FFT (Fast Fourier Transform) functionality
# - Discover NumPy's integration with other libraries in the scientific Python ecosystem
#
# [⬆️ Back to the Top](#ue4-numpy)
#
# ---
