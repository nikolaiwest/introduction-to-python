# %% [markdown]
# # **UE5: Pandas**
#
# # Chapter 00: Course Outline and Best Practices
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png" height="150">
#
# ## 🌟 Introduction to Data Analysis with Pandas
#
# Welcome to the fifth unit UE5 of the *"Introduction to Python"* programming course, focusing on **Pandas** - Python's powerful data analysis and manipulation library. Pandas bridges the gap between raw data and meaningful insights, providing intuitive data structures and tools that make working with structured data efficient and enjoyable.
#
# This course unit **"UE5: Pandas"** is designed to transform you from a Python programmer into a data analyst capable of handling real-world datasets with confidence. By the end of this unit, you'll be able to import, clean, transform, and analyze data using Pandas' comprehensive toolkit, setting a strong foundation for your journey into data science.
#
# UE5 is where you **master the essential toolkit for practical data analysis**. After learning Python fundamentals, control structures, functions, and numerical computing with NumPy, you're now ready to tackle real-world data in all its messy, complex glory. Pandas provides the bridge between programming skills and actual data analysis applications.
#
# > **Tip:** Think of Pandas as your data workbench - while the raw data is the material and Python is your toolkit, Pandas provides the specialized tools that help you shape, refine, and transform that material into something valuable.
#
# Throughout this unit, you'll learn how to work with Pandas' core data structures (`Series` and `DataFrames`), import data from various sources, clean and prepare datasets, perform complex aggregations, and derive meaningful insights from your data. These skills are fundamental for anyone working with data, from business analysts to scientific researchers to machine learning engineers.
#
# Ready to *bear* witness to the power of data analysis? Let's dive into Pandas!
#
# ---

# %% [markdown]
# ## 📚 Chapter Outline
#
# > **[Chapter 1: Introduction to Pandas](chapter-01_introduction-to-pandas.ipynb)**
# - **Overview of Pandas:** Understanding Pandas' role in the Python data ecosystem
# - **Installation and Setup:** Getting Pandas properly installed in your environment
# - **Pandas Data Structures:** Mastering Series and DataFrames - the building blocks of data analysis
#
# > **[Chapter 2: Data Manipulation with Pandas](chapter-02_data-manipulation.ipynb)**
# - **Data Importing:** Reading data from various sources (CSV, Excel, SQL, etc.)
# - **Data Exploration:** Discovering your data's characteristics with descriptive methods
# - **Data Indexing:** Selecting, filtering, and locating data with loc, iloc, and boolean indexing
# - **Data Cleaning:** Handling missing values, duplicates, and data type conversions
# - **Coding Challenge: Quality Analysis 1/3:** Analyzing plastic injection molding data with basic exploration and cleaning techniques
#
# > **[Chapter 3: Data Analysis and Aggregation](chapter-03_data-analysis-and-aggregation.ipynb)**
# - **Filtering and Sorting:** Extracting subsets of data and arranging them meaningfully
# - **Grouping and Aggregating:** Segmenting data and applying mathematical operations
# - **Pivot Tables and Cross-Tabulation:** Reshaping data for multidimensional analysis
# - **Coding Challenge: Quality Analysis 2/3:** Identifying patterns in production data through aggregation techniques
#
# > **[Chapter 4: Advanced Pandas Techniques](chapter-04_advanced-pandas-concepts.ipynb)**
# - **Time Series Analysis:** Working with dates, times, and time-indexed data
# - **Text Data Handling:** String operations, regular expressions, and text processing
# - **Combining and Merging Data Sets:** Concatenation, merging, and joining different data sources
# - **Coding Challenge: Quality Analysis 3/3:** Building a comprehensive quality prediction analysis framework
#
# ---

# %% [markdown]
# ## 💡 Best Practices and Resources
#
# ### Why Best Practices Matter in Data Analysis
#
# Data analysis is a process that combines technical skills with careful methodology. Following best practices in Pandas not only makes your code more efficient but also ensures that your analysis is accurate, reproducible, and maintainable. Proper Pandas practices deliver significant benefits:
#
# 1. **Data integrity:** Proper handling preserves the meaning and accuracy of your data, preventing subtle analysis errors
# 2. **Performance:** Optimized code runs faster and uses fewer resources, especially crucial with large datasets
# 3. **Reproducibility:** Well-structured analysis can be verified, shared, and repeated by others
# 4. **Maintainability:** Clean code is easier to update as your analysis evolves and requirements change
# 5. **Collaboration:** Standard practices make it easier for others to understand and build upon your work
#
# "There's more than one way to do it" applies strongly to Pandas - the library offers multiple approaches to the same task, but choosing the right approach can make a significant difference in readability, performance, and correctness.
#
# > **Note:** Even experienced data scientists continually refine their Pandas skills. Focus first on understanding the concepts and achieving correct results, then gradually optimize your approach as you gain experience.
#
# ### 🔧 Pandas Best Practices
#
# Here are key practices to write clean, efficient Pandas code:

# %% [markdown]
# * **Use Method Chaining:** Chain operations together for cleaner, more readable code. Most Pandas methods return a DataFrame, allowing you to apply multiple operations in sequence.
#
#   ```python
#   # Instead of separate steps:
#   df = df.dropna()
#   df = df[df['value'] > 0]
#   df = df.sort_values('date')
#
#   # Use method chaining:
#   df = (df
#         .dropna()
#         .query('value > 0')
#         .sort_values('date')
#        )
#   ```
#
#   Method chaining is one of the most powerful aspects of working with pandas. It allows you to perform multiple operations in sequence without creating intermediate variables, making your code more concise and readable.
#
#   However, when each step involves complex operations, chains can become harder to understand. Sometimes separating steps with intermediate variables adds helpful context.

# %% [markdown]
# * **Use Vectorized Operations:** Avoid loops and apply operations to entire columns at once for better performance.
#
#   ```python
#   # Slow, row-by-row approach:
#   for i in range(len(df)):
#       df.loc[i, 'celsius'] = (df.loc[i, 'fahrenheit'] - 32) * 5/9
#
#   # Fast, vectorized approach:
#   df['celsius'] = (df['fahrenheit'] - 32) * 5/9
#   ```

# %% [markdown]
# * **Choose Appropriate Indexing:** The right indexing can significantly improve query performance and make your code more readable.
#
#   ```python
#   # Set meaningful index for time series data
#   df.set_index('date', inplace=True)
#
#   # Use loc for label-based indexing:
#   jan_data = df.loc['2023-01-01':'2023-01-31']
#
#   # Use iloc for position-based indexing:
#   first_ten_rows = df.iloc[:10]
#   ```

# %% [markdown]
# * **Handle Missing Data Thoughtfully:** Consider the implications of different approaches to missing data.
#
#   ```python
#   # Understand your data before deciding:
#
#   # Drop rows with ANY missing values:
#   df_complete = df.dropna()
#
#   # Fill missing values with a strategy appropriate to your data:
#   df['numeric_col'] = df['numeric_col'].fillna(df['numeric_col'].mean())
#   df['category_col'] = df['category_col'].fillna('Unknown')
#
#   # Use interpolation for time series:
#   df['sensor_reading'] = df['sensor_reading'].interpolate(method='time')
#   ```

# %% [markdown]
# * **Use Pandas Data Types:** Properly set data types to reduce memory usage and improve performance.
#
#   ```python
#   # Convert to appropriate data types
#   df['integer_id'] = df['integer_id'].astype('int32')
#   df['small_numbers'] = df['small_numbers'].astype('float32')
#   df['category_col'] = df['category_col'].astype('category')
#   df['date_col'] = pd.to_datetime(df['date_col'])
#   ```

# %% [markdown]
# * **Prefer Standard Methods:** Use built-in Pandas functions over custom solutions wherever possible.
#
#   ```python
#   # Instead of custom logic:
#   def get_outliers(series):
#       mean = series.mean()
#       std = series.std()
#       return series[(series < mean - 2*std) | (series > mean + 2*std)]
#
#   # Use Pandas methods:
#   lower_bound = df['value'].quantile(0.25) - 1.5 * (df['value'].quantile(0.75) - df['value'].quantile(0.25))
#   upper_bound = df['value'].quantile(0.75) + 1.5 * (df['value'].quantile(0.75) - df['value'].quantile(0.25))
#   outliers = df[(df['value'] < lower_bound) | (df['value'] > upper_bound)]
#   ```

# %% [markdown]
# ### 📚 Learning Resources
#
# A curated list of resources for mastering Pandas:
#
# * **🔗 [Pandas Official Documentation](https://pandas.pydata.org/docs/):** Comprehensive reference and user guide with examples for all Pandas functionality.
#
# * **🔗 [10 Minutes to Pandas](https://pandas.pydata.org/docs/user_guide/10min.html):** Quick introduction to Pandas' core functionality - perfect for getting started.
#
# * **🔗 [Pandas Cookbook](https://github.com/jvns/pandas-cookbook):** Practical recipes for common data manipulation tasks with step-by-step explanations.
#
# * **🔗 [Python for Data Analysis](https://wesmckinney.com/book/):** The definitive guide by Pandas creator Wes McKinney, covering both basics and advanced techniques.
#
# * **🔗 [Kaggle Pandas Tutorial](https://www.kaggle.com/learn/pandas):** Hands-on exercises with real-world datasets to apply Pandas knowledge immediately.
#
# * **🔗 [Real Python's Pandas Tutorials](https://realpython.com/search?q=pandas):** In-depth articles on specific Pandas topics with practical examples.
#
# * **🔗 [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf):** Quick reference for common operations - keep this handy while coding!
#
# * **🔗 [Data School's Pandas Videos](https://www.dataschool.io/easier-data-analysis-with-pandas/):** Excellent video series for visual learners.
#
# ### ❓ Frequently Asked Questions
#
# Common questions and challenges encountered when learning Pandas:
#
# ---

# %% [markdown]
# **Q:** When should I use Pandas vs. NumPy?
#
# > **A:** Use **Pandas** when working with structured, labeled data like tables with rows and columns. Pandas excels at data cleaning, exploration, manipulation, and analysis of heterogeneous data types. It's particularly strong for time series analysis, handling missing data, and performing SQL-like operations.
# >
# > Use **NumPy** when you need to perform numerical computations on homogeneous arrays, especially large multi-dimensional arrays. NumPy is more memory-efficient and slightly faster for pure numerical calculations.
# >
# > In practice, they work well together: NumPy provides the mathematical foundation, while Pandas provides the higher-level data structures and analysis tools. Pandas uses NumPy arrays under the hood.
#
# ---

# %% [markdown]
# **Q:** How can I make my Pandas code run faster?
#
# > **A:** Several strategies can significantly improve performance:
# >
# > - **Use vectorized operations** instead of loops or apply functions
# > - **Select only the columns you need** rather than the entire DataFrame
# > - **Convert to appropriate data types** (e.g., 'category' for limited unique values)
# > - **Use query() or boolean indexing** for filtering instead of iterating
# > - **Avoid copying data unnecessarily** by understanding when Pandas returns views vs. copies
# > - **Use efficient groupby operations** with optimized aggregation functions
# > - **Consider specialized libraries** like Dask or Modin for very large datasets
# >
# > Always measure performance before and after optimization to ensure your changes are actually helping.
#
# ---

# %% [markdown]
# **Q:** What's the difference between loc and iloc in Pandas?
#
# > **A:** These indexers serve different purposes:
# >
# > - **loc** is *label-based* indexing. It accesses rows and columns by their labels (names).
# >   ```python
# >   # Get rows with index labels 'a' through 'c' and columns 'name' and 'score'
# >   df.loc['a':'c', ['name', 'score']]
# >   ```
# >
# > - **iloc** is *integer position-based* indexing. It accesses rows and columns by their integer positions.
# >   ```python
# >   # Get rows 0-2 and columns 1, 3
# >   df.iloc[0:3, [1, 3]]
# >   ```
# >
# > A helpful way to remember: **loc** uses **l**abels, while **iloc** uses **i**nteger positions.
#
# ---

# %% [markdown]
# **Q:** How should I handle the "SettingWithCopyWarning" in Pandas?
#
# > **A:** This warning occurs when you might be attempting to modify a copy of a DataFrame rather than the original, which can lead to unexpected behavior. To avoid it:
# >
# > - Understand the difference between views and copies in Pandas
# > - Use explicit copy() when you want a separate copy: `new_df = df.copy()`
# > - When modifying data, use loc for clear assignment:
# >   ```python
# >   # Instead of:
# >   subset = df[df['value'] > 0]
# >   subset['new_col'] = 1  # May raise warning
# >
# >   # Do this:
# >   df.loc[df['value'] > 0, 'new_col'] = 1  # Modifies original directly
# >
# >   # Or this if you want a separate DataFrame:
# >   subset = df[df['value'] > 0].copy()
# >   subset['new_col'] = 1  # No warning now
# >   ```
# >
# > The key is to be explicit about your intentions: whether you want to modify the original DataFrame or work with a separate copy.
#
# ---

# %% [markdown]
# **Q:** How do I handle date and time data effectively in Pandas?
#
# > **A:** Working with temporal data in Pandas involves several best practices:
# >
# > - Convert string dates to datetime using `pd.to_datetime()` as early as possible
# > - Set date columns as the index for time series data with `df.set_index('date')`
# > - Use specialized methods for date operations:
# >   ```python
# >   # Extract components
# >   df['month'] = df['date'].dt.month
# >   df['day_of_week'] = df['date'].dt.day_name()
# >
# >   # Filter by date ranges
# >   df['2023-01':'2023-03']  # When date is the index
# >
# >   # Resample time series
# >   daily_avg = df.resample('D').mean()  # Daily average
# >   monthly_sum = df.resample('M').sum()  # Monthly sum
# >   ```
# >
# > - Use the powerful `pd.date_range()` function to create date sequences
# > - Apply offset aliases (e.g., 'M', 'Q', 'A') for period-based operations
# >
# > Pandas' datetime functionality makes complex time-based analysis much simpler than with standard Python datetime objects.
#
# ---

# %% [markdown]
# [⬆️ Back to the Top](#ue5-pandas)
