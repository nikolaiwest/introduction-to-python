# %% [markdown]
# ## **Practical Exercise 1.3**: Solutions
#
# Here`s a step-by-step solution using CLI commands, with explanations for each step:
#
# ---

# %% [markdown]
# **1.  Create and change directory to the following path with the CLI commands in chapter 1.1:**
#
# `C:/repos/python-for-engineers/programs`
#
# - Navigate to directory `C:/repos/python-for-engineers`
# - Create directory `programs` with `mkdir programs`
# - Navigate into `programs` with `cd programs`
#
#
#
#
# ---

# %% [markdown]
# **2. Navigate in the CLI to the created directory and create an empty python file called `empty_testfile`.**
#
# `echo.>`:
#
# If you use Windos OS and have not yet installed Git Bash, you must use the `echo.>` function:
#
# - Navigate to `C:/repos/python-for-engineers/programs>`
# - Create file with `echo.> empty_testfile.py`
#
# ```cmd
# ----------------------------------------------
# ```
# `touch filename.py`:
#
# - Create file with `touch empy_testfile.py`
#
# ---

# %% [markdown]
# **3. Open the file with an editor like Visual Studio Code. Copy the code from above (for-loop task 1.2.3) into the testfile and save the changes. Go back to the CLI.**
#
# - Open Visual Studio Code
# - Click `File` --> `Open File`
# - Navigate (in Visual Studio Code) to `C:\repos\python-for-engineers\programs>`
# - Open `empty_testfile.py`
# - Enter python code (do not forget to indent the code):
#
# ```python
#  for i in range(3):
#      print("Hello, world!")
#      print(i+1)
# ```
#
# - Save with `Ctrl + S`
#
# ---

# %% [markdown]
# **4. Create and fill a python file called `filled_testfile` in the CLI. Fill the file with the same code (task 1.2.3 & 1.3.7). Save it.**
#
# **echo:**
#
# - `echo.> filled_testfile.py`
# Creates an empty file.
#
# - `echo for i in range(i): >> filled_testfile.py`
# - `echo    print("Hello, world!") >> filled_testfile.py`
# - `echo    print(i+1) >> filled_testfile.py`
# Adds the expression between `echo` and `>> filled_testfile.py` in the next line of the filled_testfile.py.
# *Note the indentation with 3 space bar behind the echo command followed by a normal blank space (in addition 4 blank spaces).*
#
# ```cmd
# ------------------------------------------
# ```
#
# **nano:**
#
# - `nano filled_testfile.py`
# Creates an empty Python file and opens GNU nano.
# - Copy the code.
# - `Strg + X`
# For saving the file.
# - `Y` & `Enter`
# To confirm
#
# ---

# %% [markdown]
# **5. Execute both of the created files in the CLI.**
#
# - Navigate in CLI to `C:\repos\python-for-engineers\programs>`
# - Execute file with `python testfile.py`
#
# --> `C:\repos\python-for-engineers\programs> python testfile.py`
#
# *Result:*
# ```python
# Hello, world!
# 1
# Hello, world!
# 2
# Hello, world!
# 3
# ```
