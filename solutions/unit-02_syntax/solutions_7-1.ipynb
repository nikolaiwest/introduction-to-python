# %% [markdown]
# ## 👨‍💻 Solutions 7.1: Using Modules
#
# Now it's time to apply what you've learned about modules. Complete the following tasks in a new code cell in your Jupyter Notebook:
#
# **Basic module usage:**
#
# 1. Import the `random` module and use it to generate a random number between 1 and 100.
#
# 2. Import the `datetime` module and print the current date and time. Then extract and print just the current year.
#
# 3. Import the `math` module and calculate the square root of 25 and the value of pi rounded to 2 decimal places.
#
# **Import variations:**
#
# 4. Import the `calendar` module with the alias `cal` and use it to print the calendar for the current month and year.
#
# 5. From the `random` module, import only the `choice` and `shuffle` functions. Use them to select a random element from a list and to shuffle the list.
#
# 6. Import the `platform` module and use it to print information about your operating system.
#
# Try completing these tasks on your own. If you get stuck, don't hesitate to refer back to the earlier sections. Remember to experiment with different ways of using the imported modules to reinforce your learning.

# %% [markdown]
# *Basic module usage:*

# %%
# 1. Import random and generate a random number
import random

# Generate a random number between 1 and 100
random_number = random.randint(1, 100)
print(f"Random number between 1 and 100: {random_number}")

# %%
# 2. Import datetime and work with current date/time
import datetime

# Get current date and time
current_datetime = datetime.datetime.now()
print(f"Current date and time: {current_datetime}")

# Extract just the current year
current_year = current_datetime.year
print(f"Current year: {current_year}")

# %%
# 3. Import math and perform calculations
import math

# Calculate square root of 25
sqrt_25 = math.sqrt(25)
print(f"Square root of 25: {sqrt_25}")  # 5.0

# Calculate pi rounded to 2 decimal places
pi_rounded = round(math.pi, 2)
print(f"Pi rounded to 2 decimal places: {pi_rounded}")  # 3.14

# %% [markdown]
# *Import variations:*

# %%
# 4. Import with alias
import calendar as cal
import datetime as dt

# Get current month and year
current_month = dt.datetime.now().month
current_year = dt.datetime.now().year

# Print calendar for current month
print(f"Calendar for {current_month}/{current_year}:")
print(cal.month(current_year, current_month))

# %%
# 5. Import specific functions
from random import choice, shuffle

# Create a list and use the imported functions
fruits = ["apple", "banana", "orange", "grape", "kiwi"]
print(f"Random fruit: {choice(fruits)}")

shuffle(fruits)
print(f"Shuffled fruits: {fruits}")

# %%
# 6. Import platform and get system info
import platform

print(f"System: {platform.system()}")
print(f"Platform: {platform.platform()}")
print(f"Python version: {platform.python_version()}")
print(f"Processor: {platform.processor()}")
